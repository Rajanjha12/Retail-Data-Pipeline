# %%
# %sql
-- create catalog if not exists ETL
create volume if not exists ETL.Retail.Retail_files
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr></tr></thead><tbody></tbody></table></div>

# %% [markdown]
# **Product **Table****

# %%
# %sql
 /*Transaction
 Store
 Product*/
 
 CREATE TABLE etl.retail.products (
    product_id INT PRIMARY KEY,
    product_name VARCHAR(100),
    category VARCHAR(50),
    price DECIMAL(10,2)
);
INSERT INTO etl.retail.products VALUES 
(1, 'Wireless Mouse', 'Electronics', 799.99),
(2, 'Bluetooth Speaker', 'Electronics', 1299.49),
(3, 'Yoga Mat', 'Fitness', 499.00),
(4, 'Laptop Stand', 'Accessories', 999.99),
(5, 'Notebook Set', 'Stationery', 149.00),
(6, 'Water Bottle', 'Fitness', 299.00),
(7, 'Smartwatch', 'Electronics', 4999.00),
(8, 'Desk Organizer', 'Accessories', 399.00),
(9, 'Dumbbell Set', 'Fitness', 1999.00),
(10, 'Pen Drive 32GB', 'Electronics', 599.00);
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>num_affected_rows</th><th>num_inserted_rows</th></tr></thead><tbody><tr><td>10</td><td>10</td></tr></tbody></table></div>

# %% [markdown]
# ## **Store Table**

# %%
# %python
display(df_trans)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
# %sql
select * from etl.retail.transactions
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
# %sql
CREATE TABLE etl.retail.stores (
    store_id INT PRIMARY KEY,
    store_name VARCHAR(100),
    location VARCHAR(100)
);
INSERT INTO etl.retail.stores VALUES 
(1, 'City Mall Store', 'Mumbai'),
(2, 'High Street Store', 'Delhi'),
(3, 'Tech World Outlet', 'Bangalore'),
(4, 'Downtown Mini Store', 'Pune'),
(5, 'Mega Plaza', 'Chennai');
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>num_affected_rows</th><th>num_inserted_rows</th></tr></thead><tbody><tr><td>5</td><td>5</td></tr></tbody></table></div>

# %% [markdown]
# ## **Transaction **

# %%
# %sql


 


-- Stores Table
 

 


-- Transactions Table
CREATE TABLE etl.retail.transactions (
    transaction_id INT PRIMARY KEY,
    customer_id INT,
    product_id INT,
    store_id INT,
    quantity INT,
    transaction_date DATE,
    FOREIGN KEY (product_id) REFERENCES products(product_id),
    FOREIGN KEY (store_id) REFERENCES stores(store_id)
);


INSERT INTO etl.retail.transactions VALUES (1, 127, 8, 4, 4, '2025-03-31');
INSERT INTO etl.retail.transactions VALUES (2, 105, 3, 4, 5, '2024-11-12');
INSERT INTO etl.retail.transactions VALUES (3, 116, 2, 2, 3, '2025-05-01');
INSERT INTO etl.retail.transactions VALUES (4, 120, 8, 1, 1, '2024-11-02');
INSERT INTO etl.retail.transactions VALUES (5, 105, 5, 2, 1, '2025-03-17');
INSERT INTO etl.retail.transactions VALUES (6, 110, 7, 3, 5, '2025-01-04');
INSERT INTO etl.retail.transactions VALUES (7, 110, 7, 2, 5, '2025-01-01');
INSERT INTO etl.retail.transactions VALUES (8, 126, 7, 5, 2, '2025-06-08');
INSERT INTO etl.retail.transactions VALUES (9, 123, 1, 3, 2, '2024-10-08');
INSERT INTO etl.retail.transactions VALUES (10, 124, 2, 2, 5, '2024-08-27');
INSERT INTO etl.retail.transactions VALUES (11, 102, 1, 3, 2, '2024-08-11');
INSERT INTO etl.retail.transactions VALUES (12, 108, 5, 1, 4, '2025-05-26');
INSERT INTO etl.retail.transactions VALUES (13, 104, 3, 3, 4, '2025-05-04');
INSERT INTO etl.retail.transactions VALUES (14, 120, 1, 4, 5, '2024-07-17');
INSERT INTO etl.retail.transactions VALUES (15, 121, 6, 5, 5, '2025-05-19');
INSERT INTO etl.retail.transactions VALUES (16, 118, 6, 2, 4, '2024-11-29');
INSERT INTO etl.retail.transactions VALUES (17, 109, 8, 5, 5, '2024-07-10');
INSERT INTO etl.retail.transactions VALUES (18, 103, 1, 4, 3, '2024-09-05');
INSERT INTO etl.retail.transactions VALUES (19, 116, 8, 4, 4, '2024-07-14');
INSERT INTO etl.retail.transactions VALUES (20, 130, 5, 1, 2, '2024-07-30');
INSERT INTO etl.retail.transactions VALUES (21, 105, 1, 3, 5, '2024-10-02');
INSERT INTO etl.retail.transactions VALUES (22, 107, 9, 3, 4, '2024-11-16');
INSERT INTO etl.retail.transactions VALUES (23, 122, 9, 4, 2, '2025-04-30');
INSERT INTO etl.retail.transactions VALUES (24, 125, 1, 5, 1, '2024-07-14');
INSERT INTO etl.retail.transactions VALUES (25, 116, 8, 4, 5, '2024-12-13');
INSERT INTO etl.retail.transactions VALUES (26, 126, 6, 2, 2, '2024-09-21');
INSERT INTO etl.retail.transactions VALUES (27, 127, 8, 1, 1, '2024-10-10');
INSERT INTO etl.retail.transactions VALUES (28, 101, 7, 5, 3, '2024-11-15');
INSERT INTO etl.retail.transactions VALUES (29, 119, 9, 4, 2, '2025-06-03');
INSERT INTO etl.retail.transactions VALUES (30, 116, 8, 4, 5, '2025-03-16');
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>num_affected_rows</th><th>num_inserted_rows</th></tr></thead><tbody><tr><td>1</td><td>1</td></tr></tbody></table></div>

# %%
# %python
df_trans=spark.table("etl.retail.transactions")
df_trans.write.format('parquet').mode('overwrite').save('/Volumes/etl/retail/retail_files/Bronze/Transactions/')

# %%
df_customer=spark.read.format('json').option('multiline',True).load('/Volumes/etl/retail/retail_files/Bronze/files/customers.json')
df_customer.cache()
df_customer.write.format('parquet').mode('overwrite').save('/Volumes/etl/retail/retail_files/Bronze/Customers/')

# %%
df_store=spark.table("etl.retail.stores")
df_store.write.format('parquet').mode('overwrite').save('/Volumes/etl/retail/retail_files/Bronze/stores/')

# %%
df_product=spark.table("etl.retail.products")
df_product.write.format('parquet').mode('overwrite').save('/Volumes/etl/retail/retail_files/Bronze/Products/')
